# %%
import pandas as pd
from pandas.io.json import json_normalize
import requests
from bs4 import BeautifulSoup
import folium
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h1>Data wrangling</h1>
# <p>This is the first part of this project. Here, Toronto neighborhood data is scapped from Wikipedia. Further, this data is cleaned for exploratory analysis </p>

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
html_data = requests.get(url).text

# %%
soup = BeautifulSoup(html_data, "html5lib")
table = soup.find_all("table")[0]

# %%
df = pd.DataFrame(columns=["PostalCode", "Borough", "Neighborhood"])

for row in table.find_all("tr"):
    for col in row.find_all("td"):
        PC = col.text[0:4].strip()
        TXT = col.text[4:len(col.text)].strip().replace(")", "").split("(")
        
        try:
            TXT[1]
        except:
            TXT.append(np.nan)

        
        df = df.append({"PostalCode": PC, "Borough": TXT[0], "Neighborhood": TXT[1]}, ignore_index=True)

# %%
df_updated = df[df["Borough"]!="Not assigned"].reset_index()
df_updated.drop("index", axis=1, inplace=True)

# %%
df_updated.head()
# Out:
#   PostalCode           Borough                       Neighborhood
# 0        M3A        North York                          Parkwoods
# 1        M4A        North York                   Victoria Village
# 2        M5A  Downtown Toronto         Regent Park / Harbourfront
# 3        M6A        North York  Lawrence Manor / Lawrence Heights
# 4        M7A      Queen's Park      Ontario Provincial Government

# %%
#No Duplicate postal codes
print("Total dataframe rows are: ", df_updated.shape[0], "\nTotal duplicate postal codes: ", df_updated.duplicated(subset=["PostalCode"]).value_counts())
# Out:
# Total dataframe rows are:  103
# Total duplicate postal codes:  False    103
# dtype: int64

# %%
#No Not assigned Neighborhood
df_updated[df["Neighborhood"]=="Not assigned"]
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighborhood]
# Index: []

# %%
print("Number of rows: ", df_updated.shape[0], ", Number of columns: ", df_updated.shape[1])
# Out:
# Number of rows:  103 , Number of columns:  3

# %%
geocodes = pd.read_csv("Geospatial_Coordinates.csv")
geocodes.rename(columns = {"Postal Code":"PostalCode"}, inplace=True)
geocodes.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %%
df_merged = df_updated.merge(geocodes, on="PostalCode")

# %%
df_merged.head()
# Out:
#   PostalCode           Borough                       Neighborhood   Latitude  \
# 0        M3A        North York                          Parkwoods  43.753259
# 1        M4A        North York                   Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Regent Park / Harbourfront  43.654260
# 3        M6A        North York  Lawrence Manor / Lawrence Heights  43.718518
# 4        M7A      Queen's Park      Ontario Provincial Government  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %% [markdown]
# <h1>Exploratory analysis</h1>
# <p>This part of the project deals with explore the categories of the different locations withing downtown Toronto. Foursquare RESTful API calls has been utilized to retrieve locations data.</p>

# %%
latitude = 43.6534817
longitude = -79.3839347
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, borough, neighborhood in zip(df_merged['Latitude'], df_merged['Longitude'], df_merged['Borough'], df_merged['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_6e915865071549a1b564aac868a2e5d6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6e915865071549a1b564aac868a2e5d6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_6e915865071549a1b564aac868a2e5d6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_6e915865071549a1b564aac868a2e5d6%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
CLIENT_ID = 'CRMXJD3G0DZV2VRXR52OQ5TY5LAVAVOPEQ0FDMQ1MCTLQ0B3' # your Foursquare ID
CLIENT_SECRET = 'BTGV2LNLRFVMZU2QB2OBR2OQSRHK0OBPC5FWMABX0GUZYW50' # your Foursquare Secret
ACCESS_TOKEN = '55CLD0NFKP3RMC5BFHFICIFZ50NV1TDH5VKB1EZ522QZNH54' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30

# %%
toronto_data = df_merged[df_merged['Borough'].str.contains('Toronto')].reset_index(drop=True)
toronto_data.head()
# Out:
#   PostalCode           Borough                Neighborhood   Latitude  \
# 0        M5A  Downtown Toronto  Regent Park / Harbourfront  43.654260
# 1        M5B  Downtown Toronto    Garden District, Ryerson  43.657162
# 2        M5C  Downtown Toronto              St. James Town  43.651494
# 3        M4E      East Toronto                 The Beaches  43.676357
# 4        M5E  Downtown Toronto                 Berczy Park  43.644771
#
#    Longitude
# 0 -79.360636
# 1 -79.378937
# 2 -79.375418
# 3 -79.293031
# 4 -79.373306

# %%
borough_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, borough, neighborhood in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Borough'], toronto_data['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(borough_toronto)

borough_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d72f0b14805749799edc90f826481ae6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d72f0b14805749799edc90f826481ae6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d72f0b14805749799edc90f826481ae6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d72f0b14805749799edc90f826481ae6%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
toronto_data.loc[0, 'Borough']
# Out:
# 'Downtown Toronto'

# %%
radius = 500
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            latitude, 
            longitude, 
            radius, 
            LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=CRMXJD3G0DZV2VRXR52OQ5TY5LAVAVOPEQ0FDMQ1MCTLQ0B3&client_secret=BTGV2LNLRFVMZU2QB2OBR2OQSRHK0OBPC5FWMABX0GUZYW50&v=20180604&ll=43.6534817,-79.3839347&radius=500&limit=30'

# %%
results = requests.get(url).json()

# %%
grouped_toronto = toronto_data.groupby(["Borough"]).count()

# %%
venues = results['response']['groups'][0]['items']

# %%
venue_data = pd.DataFrame(columns = ["Venue", "PostalCode", "Category", "Venue Latitude", "Venue Longitude"])

for i in venues:
    try:
        name = i['venue']['name']
        PostalCode = i['venue']['location']['postalCode'][0:3]
        category = i['venue']['categories'][0]['name']
        lat = i['venue']['location']['lat']
        lon = i['venue']['location']['lng']
        venue_data = venue_data.append({"Venue": name, "PostalCode": PostalCode, "Category": category, "Venue Latitude": lat, "Venue Longitude": lon}, ignore_index=True)
    except:
        pass

# %%
toronto_venues = df_merged.merge(venue_data, on="PostalCode")

# %%
toronto_venues.head()
# Out:
#   PostalCode           Borough              Neighborhood   Latitude  \
# 0        M5B  Downtown Toronto  Garden District, Ryerson  43.657162
# 1        M5B  Downtown Toronto  Garden District, Ryerson  43.657162
# 2        M5B  Downtown Toronto  Garden District, Ryerson  43.657162
# 3        M5B  Downtown Toronto  Garden District, Ryerson  43.657162
# 4        M5B  Downtown Toronto  Garden District, Ryerson  43.657162
#
#    Longitude                    Venue              Category  Venue Latitude  \
# 0 -79.378937                   Indigo             Bookstore       43.653515
# 1 -79.378937  CF Toronto Eaton Centre         Shopping Mall       43.654447
# 2 -79.378937                     LUSH        Cosmetics Shop       43.653557
# 3 -79.378937          Crepe Delicious  Fast Food Restaurant       43.654536
# 4 -79.378937                  SEPHORA        Cosmetics Shop       43.653527
#
#    Venue Longitude
# 0       -79.380696
# 1       -79.380952
# 2       -79.380400
# 3       -79.380889
# 4       -79.380154

# %%
borough_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, Neighborhood, category in zip(toronto_venues['Venue Latitude'], toronto_venues['Venue Longitude'], toronto_venues['Neighborhood'], toronto_venues['Category']):
    label = '{}, {}'.format(Neighborhood, category)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(borough_toronto)

borough_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a745f84f5dfc4cc59860598a1b2ebba1%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a745f84f5dfc4cc59860598a1b2ebba1%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a745f84f5dfc4cc59860598a1b2ebba1%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a745f84f5dfc4cc59860598a1b2ebba1%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# <h1>Clustering</h1>
# <p>This section is inteded to cluster neighbourhoods of toronto based on frequency of different locations.</p>

# %%
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
hoods = toronto_venues[["Neighborhood", "Category"]]
dummy_df = pd.get_dummies(hoods["Category"], prefix=None)
dummy_df.insert(loc = 0, column = "Neighborhood", value = hoods["Neighborhood"])

# %%
freq_data = dummy_df.groupby("Neighborhood").mean()
toronto_venues.head()
# Out:
#   PostalCode           Borough              Neighborhood   Latitude  \
# 0        M5B  Downtown Toronto  Garden District, Ryerson  43.657162
# 1        M5B  Downtown Toronto  Garden District, Ryerson  43.657162
# 2        M5B  Downtown Toronto  Garden District, Ryerson  43.657162
# 3        M5B  Downtown Toronto  Garden District, Ryerson  43.657162
# 4        M5B  Downtown Toronto  Garden District, Ryerson  43.657162
#
#    Longitude                    Venue              Category  Venue Latitude  \
# 0 -79.378937                   Indigo             Bookstore       43.653515
# 1 -79.378937  CF Toronto Eaton Centre         Shopping Mall       43.654447
# 2 -79.378937                     LUSH        Cosmetics Shop       43.653557
# 3 -79.378937          Crepe Delicious  Fast Food Restaurant       43.654536
# 4 -79.378937                  SEPHORA        Cosmetics Shop       43.653527
#
#    Venue Longitude
# 0       -79.380696
# 1       -79.380952
# 2       -79.380400
# 3       -79.380889
# 4       -79.380154

# %%
kclusters = 3
km = KMeans(n_clusters=kclusters)
km.fit_predict(freq_data)
# Out:
# array([2, 1, 1, 0])

# %%
freq_data.insert(0, 'Cluster Labels', km.labels_)

# %%
freq_data = freq_data.reset_index()

# %%
freq_data.head()
# Out:
#                  Neighborhood  Cluster Labels  Art Museum  Bookstore  \
# 0          Central Bay Street               2    0.166667   0.000000
# 1    Garden District, Ryerson               1    0.000000   0.083333
# 2  Richmond / Adelaide / King               1    0.000000   0.000000
# 3              St. James Town               0    0.000000   0.000000
#
#    Bubble Tea Shop  Clothing Store  Coffee Shop  Concert Hall  Cosmetics Shop  \
# 0         0.166667        0.000000     0.000000      0.000000        0.000000
# 1         0.000000        0.333333     0.000000      0.000000        0.166667
# 2         0.000000        0.000000     0.142857      0.142857        0.000000
# 3         0.000000        0.000000     0.000000      0.000000        0.000000
#
#    Department Store  ...     Hotel  Monument / Landmark     Plaza  Poke Place  \
# 0               0.0  ...  0.166667             0.000000  0.000000    0.166667
# 1               0.0  ...  0.000000             0.000000  0.083333    0.000000
# 2               0.0  ...  0.000000             0.142857  0.142857    0.000000
# 3               1.0  ...  0.000000             0.000000  0.000000    0.000000
#
#    Restaurant  Seafood Restaurant  Shopping Mall  Sushi Restaurant  Tea Room  \
# 0    0.000000            0.000000       0.000000          0.166667  0.166667
# 1    0.000000            0.000000       0.083333          0.000000  0.000000
# 2    0.142857            0.142857       0.000000          0.000000  0.000000
# 3    0.000000            0.000000       0.000000          0.000000  0.000000
#
#    Vegetarian / Vegan Restaurant
# 0                       0.000000
# 1                       0.000000
# 2                       0.142857
# 3                       0.000000
#
# [4 rows x 23 columns]

# %%
toronto_venues_new = toronto_venues.replace("Garden District, Ryerson", int(freq_data[freq_data["Neighborhood"]=="Garden District, Ryerson"]["Cluster Labels"])).replace("Richmond / Adelaide / King",int(freq_data[freq_data["Neighborhood"]=="Richmond / Adelaide / King"]["Cluster Labels"])).replace("St. James Town",int(freq_data[freq_data["Neighborhood"]=="St. James Town"]["Cluster Labels"])).replace("Central Bay Street",int(freq_data[freq_data["Neighborhood"]=="Central Bay Street"]["Cluster Labels"]))

# %%
toronto_venues_new.head()
# Out:
#   PostalCode           Borough  Neighborhood   Latitude  Longitude  \
# 0        M5B  Downtown Toronto             1  43.657162 -79.378937
# 1        M5B  Downtown Toronto             1  43.657162 -79.378937
# 2        M5B  Downtown Toronto             1  43.657162 -79.378937
# 3        M5B  Downtown Toronto             1  43.657162 -79.378937
# 4        M5B  Downtown Toronto             1  43.657162 -79.378937
#
#                      Venue              Category  Venue Latitude  \
# 0                   Indigo             Bookstore       43.653515
# 1  CF Toronto Eaton Centre         Shopping Mall       43.654447
# 2                     LUSH        Cosmetics Shop       43.653557
# 3          Crepe Delicious  Fast Food Restaurant       43.654536
# 4                  SEPHORA        Cosmetics Shop       43.653527
#
#    Venue Longitude
# 0       -79.380696
# 1       -79.380952
# 2       -79.380400
# 3       -79.380889
# 4       -79.380154

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_venues_new['Venue Latitude'], toronto_venues_new['Venue Longitude'], toronto_venues_new['Category'], toronto_venues_new["Neighborhood"]):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0c7a468a795348a5b0f2c48edfc8aa6f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0c7a468a795348a5b0f2c48edfc8aa6f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0c7a468a795348a5b0f2c48edfc8aa6f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0c7a468a795348a5b0f2c48edfc8aa6f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
toronto_venues_new = toronto_venues_new.rename(columns = {"Neighborhood":"Clusters"})

# %%
toronto_venues_new.insert(loc=0, column = "Neighborhood", value=toronto_venues["Neighborhood"])

# %%
toronto_venues_new.head()
# Out:
#                Neighborhood PostalCode           Borough  clusters   Latitude  \
# 0  Garden District, Ryerson        M5B  Downtown Toronto         1  43.657162
# 1  Garden District, Ryerson        M5B  Downtown Toronto         1  43.657162
# 2  Garden District, Ryerson        M5B  Downtown Toronto         1  43.657162
# 3  Garden District, Ryerson        M5B  Downtown Toronto         1  43.657162
# 4  Garden District, Ryerson        M5B  Downtown Toronto         1  43.657162
#
#    Longitude                    Venue              Category  Venue Latitude  \
# 0 -79.378937                   Indigo             Bookstore       43.653515
# 1 -79.378937  CF Toronto Eaton Centre         Shopping Mall       43.654447
# 2 -79.378937                     LUSH        Cosmetics Shop       43.653557
# 3 -79.378937          Crepe Delicious  Fast Food Restaurant       43.654536
# 4 -79.378937                  SEPHORA        Cosmetics Shop       43.653527
#
#    Venue Longitude
# 0       -79.380696
# 1       -79.380952
# 2       -79.380400
# 3       -79.380889
# 4       -79.380154

# %%
toronto_venues_new[toronto_venues_new["clusters"]==0]
# Out:
#       Neighborhood PostalCode           Borough  clusters   Latitude  \
# 12  St. James Town        M5C  Downtown Toronto         0  43.651494
#
#     Longitude         Venue          Category  Venue Latitude  Venue Longitude
# 12 -79.375418  Hudson's Bay  Department Store        43.65204       -79.380391

# %%
toronto_venues_new[toronto_venues_new["clusters"]==1]
# Out:
#                   Neighborhood PostalCode           Borough  clusters  \
# 0     Garden District, Ryerson        M5B  Downtown Toronto         1
# 1     Garden District, Ryerson        M5B  Downtown Toronto         1
# 2     Garden District, Ryerson        M5B  Downtown Toronto         1
# 3     Garden District, Ryerson        M5B  Downtown Toronto         1
# 4     Garden District, Ryerson        M5B  Downtown Toronto         1
# 5     Garden District, Ryerson        M5B  Downtown Toronto         1
# 6     Garden District, Ryerson        M5B  Downtown Toronto         1
# 7     Garden District, Ryerson        M5B  Downtown Toronto         1
# 8     Garden District, Ryerson        M5B  Downtown Toronto         1
# 9     Garden District, Ryerson        M5B  Downtown Toronto         1
# 10    Garden District, Ryerson        M5B  Downtown Toronto         1
# 11    Garden District, Ryerson        M5B  Downtown Toronto         1
# 19  Richmond / Adelaide / King        M5H  Downtown Toronto         1
# 20  Richmond / Adelaide / King        M5H  Downtown Toronto         1
# 21  Richmond / Adelaide / King        M5H  Downtown Toronto         1
# 22  Richmond / Adelaide / King        M5H  Downtown Toronto         1
# 23  Richmond / Adelaide / King        M5H  Downtown Toronto         1
# 24  Richmond / Adelaide / King        M5H  Downtown Toronto         1
# 25  Richmond / Adelaide / King        M5H  Downtown Toronto         1
#
#      Latitude  Longitude                                        Venue  \
# 0   43.657162 -79.378937                                       Indigo
# 1   43.657162 -79.378937                      CF Toronto Eaton Centre
# 2   43.657162 -79.378937                                         LUSH
# 3   43.657162 -79.378937                              Crepe Delicious
# 4   43.657162 -79.378937                                      SEPHORA
# 5   43.657162 -79.378937                                  UNIQLO ユニクロ
# 6   43.657162 -79.378937                                    Nordstrom
# 7   43.657162 -79.378937                          lululemon athletica
# 8   43.657162 -79.378937                           Apple Eaton Centre
# 9   43.657162 -79.378937                                    HomeSense
# 10  43.657162 -79.378937                                        Roots
# 11  43.657162 -79.378937                          Yonge-Dundas Square
# 19  43.650571 -79.384568                       Nathan Phillips Square
# 20  43.650571 -79.384568                                Old City Hall
# 21  43.650571 -79.384568  Four Seasons Centre for the Performing Arts
# 22  43.650571 -79.384568       The Keg Steakhouse + Bar - York Street
# 23  43.650571 -79.384568                         Bulldog On The Block
# 24  43.650571 -79.384568                     John & Sons Oyster House
# 25  43.650571 -79.384568                                    Rosalinda
#
#                          Category  Venue Latitude  Venue Longitude
# 0                       Bookstore       43.653515       -79.380696
# 1                   Shopping Mall       43.654447       -79.380952
# 2                  Cosmetics Shop       43.653557       -79.380400
# 3            Fast Food Restaurant       43.654536       -79.380889
# 4                  Cosmetics Shop       43.653527       -79.380154
# 5                  Clothing Store       43.655910       -79.380641
# 6                  Clothing Store       43.655041       -79.380966
# 7                  Clothing Store       43.653286       -79.380764
# 8               Electronics Store       43.652832       -79.380555
# 9          Furniture / Home Store       43.653149       -79.379418
# 10                 Clothing Store       43.653613       -79.380244
# 11                          Plaza       43.656054       -79.380495
# 19                          Plaza       43.652270       -79.383516
# 20            Monument / Landmark       43.652009       -79.381744
# 21                   Concert Hall       43.650592       -79.385806
# 22                     Restaurant       43.649987       -79.384103
# 23                    Coffee Shop       43.650652       -79.384141
# 24             Seafood Restaurant       43.650656       -79.381613
# 25  Vegetarian / Vegan Restaurant       43.650252       -79.385156

# %%
toronto_venues_new[toronto_venues_new["clusters"]==2]
# Out:
#           Neighborhood PostalCode           Borough  clusters   Latitude  \
# 13  Central Bay Street        M5G  Downtown Toronto         2  43.657952
# 14  Central Bay Street        M5G  Downtown Toronto         2  43.657952
# 15  Central Bay Street        M5G  Downtown Toronto         2  43.657952
# 16  Central Bay Street        M5G  Downtown Toronto         2  43.657952
# 17  Central Bay Street        M5G  Downtown Toronto         2  43.657952
# 18  Central Bay Street        M5G  Downtown Toronto         2  43.657952
#
#     Longitude                                         Venue          Category  \
# 13 -79.387383                                     Poke Guys        Poke Place
# 14 -79.387383                      Textile Museum of Canada        Art Museum
# 15 -79.387383                                       Japango  Sushi Restaurant
# 16 -79.387383                                       Tsujiri          Tea Room
# 17 -79.387383                                  Chatime 日出茶太   Bubble Tea Shop
# 18 -79.387383  Marriott Downtown at CF Toronto Eaton Centre             Hotel
#
#     Venue Latitude  Venue Longitude
# 13       43.654895       -79.385052
# 14       43.654396       -79.386500
# 15       43.655268       -79.385165
# 16       43.655374       -79.385354
# 17       43.655542       -79.384684
# 18       43.654728       -79.382422
